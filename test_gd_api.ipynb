# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Collecting google-api-python-client
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/3d/7e/ddf1a1e19e00800005833f5bddd8576d93d22d4a4dda241ae3c8c4aecb1f/google_api_python_client-2.101.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.101.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-auth-httplib2
#   Obtaining dependency information for google-auth-httplib2 from https://files.pythonhosted.org/packages/d3/3d/e4991229886c0d522d9552151a43ff7adcc61e026e60ce8bd508387f84cf/google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting google-auth-oauthlib
#   Obtaining dependency information for google-auth-oauthlib from https://files.pythonhosted.org/packages/ce/33/a907b4b67245647746dde8d61e1643ef5d210c88e090d491efd89eff9f95/google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting httplib2<1.dev0,>=0.15.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.9/96.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-api-python-client) (2.20.0)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/4d/ce/4fd62ea66b3508debc795e475336ce915929765870f0ad52328426ba016e/google_api_core-2.12.0-py3-none-any.whl.metadata
#   Downloading google_api_core-2.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/a7/bc/416a1ffeba4dcd072bc10523dac9ed97f2e7fc4b760580e2bdbdc1e2afdd/googleapis_common_protos-1.60.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 from https://files.pythonhosted.org/packages/5e/46/5b9674a33cbf690ffdd79ab1863767a66461cd06ea7aeb9f90e4e50be7a5/protobuf-4.24.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.24.3-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.28.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\tinma\appdata\roaming\python\python310\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.26.14)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tinma\appdata\roaming\python\python310\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tinma\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2022.12.7)
# Downloading google_api_python_client-2.101.0-py2.py3-none-any.whl (12.3 MB)
#    ---------------------------------------- 12.3/12.3 MB 508.9 kB/s eta 0:00:00
# Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl (9.3 kB)
# Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Downloading google_api_core-2.12.0-py3-none-any.whl (121 kB)
#    -------------------------------------- 121.4/121.4 kB 356.4 kB/s eta 0:00:00
# Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
#    -------------------------------------- 227.6/227.6 kB 479.9 kB/s eta 0:00:00
# Downloading protobuf-4.24.3-cp310-abi3-win_amd64.whl (430 kB)
#    -------------------------------------- 430.5/430.5 kB 707.5 kB/s eta 0:00:00
# Installing collected packages: uritemplate, protobuf, oauthlib, httplib2, requests-oauthlib, googleapis-common-protos, google-auth-oauthlib, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.12.0 google-api-python-client-2.101.0 google-auth-httplib2-0.1.1 google-auth-oauthlib-1.1.0 googleapis-common-protos-1.60.0 httplib2-0.22.0 oauthlib-3.2.2 protobuf-4.24.3 requests-oauthlib-1.3.1 uritemplate-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mysql-connector-python 8.0.33 requires protobuf<=3.20.3,>=3.11.0, but you have protobuf 4.24.3 which is incompatible.

# %%
import pandas as pd

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google.oauth2 import service_account

# If modifying these scopes, delete the file token.json.

SCOPES = ['https://www.googleapis.com/auth/drive.readonly','https://www.googleapis.com/auth/devstorage.full_control','https://www.googleapis.com/auth/drive']
SERVICE_ACCOUNT_FILE = './credentials/fiery-protocol-399500-f2566dd92ef4.json'

creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

try:
    service = build('drive', 'v3', credentials=creds)

    # Call the Drive v3 API
    results = service.files().list(
        corpora='user', includeItemsFromAllDrives=True, supportsAllDrives=True, fields="*").execute() # fields='nextPageToken, files(id, name)'
    if items := results.get('files', []):
        print('Files:')
        # dfx = pd.DataFrame()
        for item in items:
            # dfy = [item['id'],item['name'],item['kind'],item['mimeType'],item['createdTime'],item['modifiedTime'],item['sharedWithMeTime'],item['ownedByMe'],item['capabilities']['canDownload']]
            print(u'{0} ({1})'.format(item['name'], item['id']))
            # dfy = pd.DataFrame(dfy,columns=['id','name','kind','mimeType','createdTime','modifiedTime','sharedWithMeTime','ownedByMe','canDownload','parents'])
            
    else:
        print('No files found.')

    print(item)
except HttpError as error:
    # TODO(developer) - Handle errors from drive API.
    print(f'An error occurred: {error}')


# if __name__ == '__main__':
#     main()
# Out:
# Files:
# yelp (1IcC0SiBY2UeyRUn7gcs2PfIhwptvDRdk)
# review.json (1VHL_TmiZJErHTAGR2XT3Zp3RGrEqs6N7)
# user.parquet (1vgLvlnvshuHAX7fvdZFjFHgYIlTtPgX2)
# checkin.json (1A2VPJVr-afg0RyYs5YHCSFHnDMyAkKn3)
# tip.json (1HlAOVDW01W1EUpqoe7XzdG8pHDDkVMiN)
# business.pkl (1EDQxMvVjI5j4hj33YOxQSifqsNkJiVaU)
# checkin.json (1ZOTajlDNwnVsjyxQ_YsjKsKZzz3P07Is)
# review_california (1ikEacrw5YaD3_yZQK7OOArN1VjGXJOhh)
# 15.json (18v7FqrWpkWzfGuvsEufpLqfSX5cBzedZ)
# 14.json (1E1C1sMWLl5O7lv7-3F-dHiiANiluVzau)
# 12.json (16zR3L9yW8LN13sv6UKTVvNFIV5qiaf9K)
# 11.json (19ulT839gsCiBiijd03NCwEguQ1AHqHlS)
# 18.json (1_wIVuT5XGBMT24UY8KceL5n9naY0igSa)
# 9.json (1MaaDGvYPV55vBDFhur8sQob5PL0Er64B)
# 13.json (1bMTc79flSkTbxsOI6AsMzDUrVJnUl4gb)
# 16.json (1s32njINk67_Jg3cLgZoPRAeEfGPZXhFP)
# 17.json (1koSgbS-6FX0GvUh720lrj5ZITRQ9kL3r)
# 10.json (1vGKSRnVAha5d0zBcKWud8t2vJOX-SQ_2)
# 1.json (14Uo6AcNhy1TS0NFkXe_ClowboEpOGR8S)
# 6.json (1G4fJb6EcF8VhCj9AnWwTTHeXvhgklCpW)
# 4.json (1H-3ORy9gs_aiYlhBbSlAKtvFGG3hIgbB)
# 8.json (1YcbMk_OKuXQkoLHzEPfefS_4ZbQ2ljWM)
# 3.json (1ZWTs6XiXL6ZKxN54XaTET3nIZSXoQcur)
# 7.json (1mZRoecf1VAiwTj1--ZqyHOVAa1Nn16FV)
# 5.json (1qOegXmjwBpFCVtupe9YlqUXcM6VQtTfH)
# 2.json (1r1XykO0Ladf8CLHVn_diJtrV4c0y68hw)
# review_colorado (13FmmDFGjcMacTm9bLEeq9yO7BESLprIK)
# review_texas (1u-q7_KBPQlKuICsjorm0nQR8CRhkImKc)
# review_georgia (1bB7j6_ojiSZSm7WYZ2Sue67qrShQNMit)
# metadata_maps (1FrOLWoLdPDyi1h7BKT5z-LSGjuMxIyKb)
# 5.json (12XSv3ozrMDEzgfV7tenwPVFTE3RoYDfX)
# 4.json (15Fje-mtJi5S31DFZUdLWOSvhG43J3yNz)
# 13.json (1K7gB9SYeNbYsA3CnyD-LZAI-fPSKUSkG)
# 12.json (15W8jflXNy8GC7ZAW8aHoSbKtZNLyFQ53)
# 8.json (15ekokSQY4OAxdSEssA2z0QirJm9Zs67M)
# 6.json (1CZ2Fy0KNI6LpOcM7PlISju5Q_FcL4EFq)
# 10.json (1OdI3KyY199Z76BnHpuZOK5HqodexRzRl)
# 11.json (1VRoZ1X6BJ4O2iAlif1LPTRt60zTjmslX)
# 7.json (1_Tk8WUJy97JSQJWtLJydZLTCAAK7stX7)
# 9.json (1fqcOvlhCHYaSyp3sx-mv0phB5MlSZLzR)
# 2.json (1B06zqMo0BfA97PcDovp_9NOdbxLYtZgJ)
# 1.json (1SVxpM8wvELksT-p99tAGszx6P_t4fY6z)
# 3.json (1Wh9LUvZMnFKHmrf2qyE3Id0qTT9TY6Kz)
# review_newyork (1fNf7hKTn9W3XVtbeKN_w7G_eVVviFCR0)
# 15.json (1-APD3unu3q_NJs-_YlxCz_J7knm3EVpn)
# 8.json (14Y9WX25_qaagO3R2nPUgN43ibdeyBflh)
# 5.json (14cjkbDcjNyzbjsVqUv8MmzM5WRIgOXcS)
# 13.json (1FdAeskoct5KNwiQOr4sGADgkwW4PhGoC)
# 3.json (1BozdjEbkfrCqpkePtMpgd0XjUkZwwc6N)
# 17.json (1MFaqNRwjpW3jcq9AVX_mkfblnnH8WUY1)
# 10.json (1MgGjIKgmx2GptVwQLQtFEsApbPjucdtV)
# 4.json (1OZLDU28VReJH2Ra6hZ7VoxRJFa-WAFcm)
# 6.json (1UWNU0IDoE26OjfV5QsnXWPdTe__Otprj)
# 18.json (1WcqliKCGfsKvvahAuB82aVxvebuO3ozU)
# 9.json (1gZ0CI32HPNCpVgTh_B-tyb2sg-G_8JLZ)
# 2.json (1kHNfw7O4KIhXj_PLZk18R-niAiKp6hl5)
# 12.json (1mU9PHCPJq2E0dkFJZTO1wWROmbKsueLn)
# 14.json (1noROckWfxEf-_6J-T5-1nawfAjz3STUo)
# 11.json (1qtQodPCWXRbAFMq1NQUdANSntDGyVZ8A)
# 1.json (1sj5xiGpJ4Tv6xG70tPOI0VoHBQOGBXIX)
# 16.json (1uMqJcA8WZxOX0sqbvKpCkqgQcW3LPztG)
# 7.json (1xF1BYiFuDEEwayofyTeHQcokSsfymaBJ)
# 13.json (17EmEMd-P4n4AuNtEo6C1k3usUKEs4Pvm)
# 5.json (1BO0IZhPWInVqO6fkOfKNFJWYig_8hGns)
# 7.json (1DjMV5sKMZ-s5FH1KYAfoD7y8n3FQRPrQ)
# 12.json (1JjbKZj-SeRpLcYlyJ6q5x-h1MBj8IxRL)
# 6.json (1OlzWBUoxsRFtD4AK3iPjebB5rP1pFj3O)
# 4.json (1QQ_PcJCY_1WkOu9eIJj4iy0NrkkqkbVm)
# 16.json (1Rw5Av9WoAUbibzFCMgZsgx4A2_LJtfNz)
# 1.json (1SoQoSVBqKs7kXiKjtyXV6S2jRkMOteOB)
# 15.json (1W9wOMZkocso2a_QIxHd67DaKoGsdfg5H)
# 3.json (1XAuSlhLErNhU7zVGQuTuc2iudndbDMoS)
# 8.json (1YxqOsVZzDAQVqU-4pOkW-1EiABiO6Tcz)
# 14.json (1Z4Sv_Km2cp4CMq_rm1PA-QlmThAq0CJE)
# 2.json (1aBcJx0faVkZAOlUYw2MaXIp0pthnr_IK)
# 10.json (1eRXiyoSfPMaydafdl5tmLQC31CepWIXb)
# 11.json (1n6rDpbx0DOFT6Y4R4MMgXB-Qd0pVeS4F)
# 9.json (1ojn00YpfWcyRei7vDKwpAJ0XCKKzDNvI)
# 8.json (1A_bWp2pe9ZbA_Yj81aBbjqdJrnN8c1OV)
# 4.json (1QV-G-jExo-g2i6SisWoKaPh1SmtBozOZ)
# 1.json (1WmGDWhoI8bS4FxWOLq_s-vE65wdzkGY1)
# 7.json (1b8-FtF2ijdLICINE1ZAR2yQBsaRli3PZ)
# 2.json (1e3_nHsgCoudzjwSApfQEfDm8GWlTNTIV)
# 6.json (1fV9yoPtCqxgnnBFW46ey21JAyeTv3fW5)
# 9.json (1i7FjI982YFJ2G4DQHHYKJOSlZ3zoAIAy)
# 3.json (1mDE2-MLkrGjmlyVKP0GTnG2GwqoVDzV7)
# 5.json (1s445MNM-ZmTJ9Uv31MYFKzHY_99ufm7C)
# 10.json (1uZHJnWcRdLH2L8BpFeqbYN77GrLfmHUU)
# 11.json (1kv_5u13hYrMEF3jfuzM7vEDFlzPlO1D-)
# 9.json (1-JXGt4f8IukY-Lm24_c8B98uORFNhYL2)
# 16.json (114faJBc7PQIYWpaW3yck1EsNgZYFXhma)
# 8.json (137SpnCjTD-7IpVEExgLQGFcWI2Wqhln6)
# 7.json (17Zi1APcn-bQeEZ-hP-rjOXp1BbQLbVtq)
# 15.json (1BRI-atJ633vW9ntFdVDJdjlNhqxI9rF5)
# 12.json (1VvWW1y3i8qwYT2JupEb8owTrEMTM_mXs)
# 10.json (1WoFHT1S7UcVJqSu9J_oYKv9jpumcS48t)
# 11.json (1a7XSZ7XC8ucN7IHO4Up_0b1L3KhRljHn)
# 13.json (1ekfvgrL1Mrf7VrPzmbEZYPWYp_0rSwTY)
# 14.json (1ub2I2RXNlWCTRoYeL-CFaVfjSwrv5s2e)
# 3.json (1RmCC5LA0w1ny-0-2xqp4TnNUCmT0XEZL)
# {'kind': 'drive#file', 'fileExtension': 'json', 'copyRequiresWriterPermission': False, 'md5Checksum': 'cb56ade3f0d5f2bbe27595241edaddd0', 'writersCanShare': True, 'viewedByMe': False, 'mimeType': 'application/json', 'parents': ['13FmmDFGjcMacTm9bLEeq9yO7BESLprIK'], 'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/json', 'shared': True, 'lastModifyingUser': {'displayName': 'tinmar andrade', 'kind': 'drive#user', 'me': False, 'permissionId': '03209325635839904128', 'emailAddress': 'tinmar96@gmail.com', 'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}, 'owners': [{'displayName': 'tinmar andrade', 'kind': 'drive#user', 'me': False, 'permissionId': '03209325635839904128', 'emailAddress': 'tinmar96@gmail.com', 'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}], 'headRevisionId': '0B19oBnxhxNcdWlUveERXUU5ZSmppMnQ4ajFXeTREVFlFQWlnPQ', 'webViewLink': 'https://drive.google.com/file/d/1RmCC5LA0w1ny-0-2xqp4TnNUCmT0XEZL/view?usp=drivesdk', 'webContentLink': 'https://drive.google.com/uc?id=1RmCC5LA0w1ny-0-2xqp4TnNUCmT0XEZL&export=download', 'size': '47861337', 'viewersCanCopyContent': True, 'permissions': [{'id': '05541557612097694608', 'displayName': 'henry-project@fiery-protocol-399500.iam.gserviceaccount.com', 'type': 'user', 'kind': 'drive#permission', 'photoLink': 'https://lh3.googleusercontent.com/a/default-user=s64', 'emailAddress': 'henry-project@fiery-protocol-399500.iam.gserviceaccount.com', 'role': 'writer', 'deleted': False, 'pendingOwner': False}, {'id': '03209325635839904128', 'displayName': 'tinmar andrade', 'type': 'user', 'kind': 'drive#permission', 'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64', 'emailAddress': 'tinmar96@gmail.com', 'role': 'owner', 'deleted': False, 'pendingOwner': False}], 'hasThumbnail': False, 'spaces': ['drive'], 'id': '1RmCC5LA0w1ny-0-2xqp4TnNUCmT0XEZL', 'name': '3.json', 'starred': False, 'trashed': False, 'explicitlyTrashed': False, 'createdTime': '2023-10-02T01:20:38.176Z', 'modifiedTime': '2023-10-02T01:21:56.269Z', 'quotaBytesUsed': '47861337', 'version': '5', 'originalFilename': 'Copia de 3.json', 'ownedByMe': False, 'fullFileExtension': 'json', 'isAppAuthorized': False, 'capabilities': {'canChangeViewersCanCopyContent': False, 'canEdit': True, 'canCopy': True, 'canComment': True, 'canAddChildren': False, 'canDelete': False, 'canDownload': True, 'canListChildren': False, 'canRemoveChildren': False, 'canRename': True, 'canTrash': False, 'canReadRevisions': True, 'canChangeCopyRequiresWriterPermission': False, 'canMoveItemIntoTeamDrive': False, 'canUntrash': False, 'canModifyContent': True, 'canMoveItemOutOfDrive': False, 'canAddMyDriveParent': False, 'canRemoveMyDriveParent': True, 'canMoveItemWithinDrive': True, 'canShare': True, 'canMoveChildrenWithinDrive': False, 'canModifyContentRestriction': True, 'canChangeSecurityUpdateEnabled': False, 'canAcceptOwnership': False, 'canReadLabels': False, 'canModifyLabels': False, 'canModifyEditorContentRestriction': True, 'canModifyOwnerContentRestriction': False, 'canRemoveContentRestriction': False}, 'thumbnailVersion': '0', 'modifiedByMe': False, 'linkShareMetadata': {'securityUpdateEligible': False, 'securityUpdateEnabled': True}, 'sha1Checksum': 'c6fa430870b52e85a8886cdcf78e1c35e04f2b9c', 'sha256Checksum': '0e9616911c5d63ca2156a5c135df2ba86840723b340b01d3719879cca2730cb0'}

# %%
items

# 'kind','mimeType','name','id','createdTime','modifiedTime','sharedWithMeTime','ownedByMe','capabilities : canDownload'
# Out:
# [{'kind': 'drive#file',
#   'copyRequiresWriterPermission': False,
#   'writersCanShare': True,
#   'viewedByMe': False,
#   'mimeType': 'application/vnd.google-apps.folder',
#   'parents': ['1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP'],
#   'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder+shared',
#   'shared': True,
#   'lastModifyingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'owners': [{'displayName': 'tinmar andrade',
#     'kind': 'drive#user',
#     'me': False,
#     'permissionId': '03209325635839904128',
#     'emailAddress': 'tinmar96@gmail.com',
#     'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}],
#   'webViewLink': 'https://drive.google.com/drive/folders/1mC-zYhQ5b2vVr3wvsRSE9DDwB-4rL2y8',
#   'viewersCanCopyContent': True,
#   'hasThumbnail': False,
#   'spaces': ['drive'],
#   'folderColorRgb': '#8f8f8f',
#   'id': '1mC-zYhQ5b2vVr3wvsRSE9DDwB-4rL2y8',
#   'name': 'prueba',
#   'starred': False,
#   'trashed': False,
#   'explicitlyTrashed': False,
#   'createdTime': '2023-09-27T10:01:36.175Z',
#   'modifiedTime': '2023-09-27T10:01:36.175Z',
#   'quotaBytesUsed': '0',
#   'version': '1',
#   'ownedByMe': False,
#   'isAppAuthorized': False,
#   'capabilities': {'canChangeViewersCanCopyContent': False,
#    'canEdit': False,
#    'canCopy': False,
#    'canComment': False,
#    'canAddChildren': False,
#    'canDelete': False,
#    'canDownload': True,
#    'canListChildren': True,
#    'canRemoveChildren': False,
#    'canRename': False,
#    'canTrash': False,
#    'canReadRevisions': False,
#    'canChangeCopyRequiresWriterPermission': False,
#    'canMoveItemIntoTeamDrive': False,
#    'canUntrash': False,
#    'canModifyContent': False,
#    'canMoveItemOutOfDrive': False,
#    'canAddMyDriveParent': False,
#    'canRemoveMyDriveParent': True,
#    'canMoveItemWithinDrive': False,
#    'canShare': False,
#    'canMoveChildrenWithinDrive': False,
#    'canModifyContentRestriction': False,
#    'canChangeSecurityUpdateEnabled': False,
#    'canAcceptOwnership': False,
#    'canReadLabels': False,
#    'canModifyLabels': False,
#    'canModifyEditorContentRestriction': False,
#    'canModifyOwnerContentRestriction': False,
#    'canRemoveContentRestriction': False},
#   'thumbnailVersion': '0',
#   'modifiedByMe': False,
#   'linkShareMetadata': {'securityUpdateEligible': False,
#    'securityUpdateEnabled': True}},
#  {'kind': 'drive#file',
#   'fileExtension': 'docx',
#   'copyRequiresWriterPermission': False,
#   'md5Checksum': '84f8366527335bd0b32113579b885122',
#   'writersCanShare': True,
#   'viewedByMe': False,
#   'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'parents': ['1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP'],
#   'thumbnailLink': 'https://lh3.googleusercontent.com/drive-storage/AKHj6E7HIH6zYL6hhEe4Wb_TMbklBTT4tw2PszheIy_mFWR-jh_zh9VFb4bgtoglDL12JrAI9IoxOlpBZNlXxihR0iVOpNy-XVpvvXQp0INV=s220',
#   'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'shared': True,
#   'lastModifyingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'owners': [{'displayName': 'tinmar andrade',
#     'kind': 'drive#user',
#     'me': False,
#     'permissionId': '03209325635839904128',
#     'emailAddress': 'tinmar96@gmail.com',
#     'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}],
#   'headRevisionId': '0B19oBnxhxNcdblZHb09kN3pqUWh2Uk1XY3JWRERobDF2VUhZPQ',
#   'webViewLink': 'https://docs.google.com/document/d/1t2lPMbWu3i_ZeZsKoDM3uT_ypltyKw_y/edit?usp=drivesdk&ouid=109730341896447223533&rtpof=true&sd=true',
#   'webContentLink': 'https://drive.google.com/uc?id=1t2lPMbWu3i_ZeZsKoDM3uT_ypltyKw_y&export=download',
#   'size': '31629',
#   'viewersCanCopyContent': True,
#   'hasThumbnail': True,
#   'spaces': ['drive'],
#   'id': '1t2lPMbWu3i_ZeZsKoDM3uT_ypltyKw_y',
#   'name': 'Copia de Temas emergentes.docx',
#   'starred': False,
#   'trashed': False,
#   'explicitlyTrashed': False,
#   'createdTime': '2023-09-27T08:53:05.591Z',
#   'modifiedTime': '2023-09-27T08:53:05.591Z',
#   'quotaBytesUsed': '31629',
#   'version': '5',
#   'originalFilename': 'Copia de Temas emergentes.docx',
#   'ownedByMe': False,
#   'fullFileExtension': 'docx',
#   'isAppAuthorized': False,
#   'capabilities': {'canChangeViewersCanCopyContent': False,
#    'canEdit': False,
#    'canCopy': True,
#    'canComment': False,
#    'canAddChildren': False,
#    'canDelete': False,
#    'canDownload': True,
#    'canListChildren': False,
#    'canRemoveChildren': False,
#    'canRename': False,
#    'canTrash': False,
#    'canReadRevisions': False,
#    'canChangeCopyRequiresWriterPermission': False,
#    'canMoveItemIntoTeamDrive': False,
#    'canUntrash': False,
#    'canModifyContent': False,
#    'canMoveItemOutOfDrive': False,
#    'canAddMyDriveParent': False,
#    'canRemoveMyDriveParent': True,
#    'canMoveItemWithinDrive': False,
#    'canShare': False,
#    'canMoveChildrenWithinDrive': False,
#    'canModifyContentRestriction': False,
#    'canChangeSecurityUpdateEnabled': False,
#    'canAcceptOwnership': False,
#    'canReadLabels': False,
#    'canModifyLabels': False,
#    'canModifyEditorContentRestriction': False,
#    'canModifyOwnerContentRestriction': False,
#    'canRemoveContentRestriction': False},
#   'thumbnailVersion': '1',
#   'modifiedByMe': False,
#   'linkShareMetadata': {'securityUpdateEligible': False,
#    'securityUpdateEnabled': True},
#   'sha1Checksum': 'eabe9e878e222ce9155b3ef4bba0b51568a4c657',
#   'sha256Checksum': 'cd0428e165f09ae60e4a95f55e62557f4c1f87fba902ad640dca9702c0f8c999'},
#  {'kind': 'drive#file',
#   'copyRequiresWriterPermission': False,
#   'writersCanShare': True,
#   'viewedByMe': False,
#   'mimeType': 'application/vnd.google-apps.folder',
#   'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder+shared',
#   'shared': True,
#   'lastModifyingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'owners': [{'displayName': 'tinmar andrade',
#     'kind': 'drive#user',
#     'me': False,
#     'permissionId': '03209325635839904128',
#     'emailAddress': 'tinmar96@gmail.com',
#     'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}],
#   'sharingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'webViewLink': 'https://drive.google.com/drive/folders/1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP',
#   'viewersCanCopyContent': True,
#   'hasThumbnail': False,
#   'spaces': ['drive'],
#   'folderColorRgb': '#8f8f8f',
#   'id': '1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP',
#   'name': 'Mathematics',
#   'starred': False,
#   'trashed': False,
#   'explicitlyTrashed': False,
#   'createdTime': '2018-09-24T23:51:44.084Z',
#   'modifiedTime': '2023-09-27T07:04:00.730Z',
#   'sharedWithMeTime': '2023-09-27T05:39:22.673Z',
#   'quotaBytesUsed': '0',
#   'version': '12',
#   'ownedByMe': False,
#   'isAppAuthorized': False,
#   'capabilities': {'canChangeViewersCanCopyContent': False,
#    'canEdit': False,
#    'canCopy': False,
#    'canComment': False,
#    'canAddChildren': False,
#    'canDelete': False,
#    'canDownload': True,
#    'canListChildren': True,
#    'canRemoveChildren': False,
#    'canRename': False,
#    'canTrash': False,
#    'canReadRevisions': False,
#    'canChangeCopyRequiresWriterPermission': False,
#    'canMoveItemIntoTeamDrive': False,
#    'canUntrash': False,
#    'canModifyContent': False,
#    'canMoveItemOutOfDrive': False,
#    'canAddMyDriveParent': False,
#    'canRemoveMyDriveParent': True,
#    'canMoveItemWithinDrive': False,
#    'canShare': False,
#    'canMoveChildrenWithinDrive': False,
#    'canModifyContentRestriction': False,
#    'canChangeSecurityUpdateEnabled': False,
#    'canAcceptOwnership': False,
#    'canReadLabels': False,
#    'canModifyLabels': False,
#    'canModifyEditorContentRestriction': False,
#    'canModifyOwnerContentRestriction': False,
#    'canRemoveContentRestriction': False},
#   'thumbnailVersion': '0',
#   'modifiedByMe': False,
#   'linkShareMetadata': {'securityUpdateEligible': False,
#    'securityUpdateEnabled': True}},
#  {'kind': 'drive#file',
#   'copyRequiresWriterPermission': False,
#   'writersCanShare': True,
#   'viewedByMe': False,
#   'mimeType': 'application/vnd.google-apps.document',
#   'exportLinks': {'application/rtf': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=rtf',
#    'application/vnd.oasis.opendocument.text': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=odt',
#    'text/html': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=html',
#    'application/pdf': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=pdf',
#    'application/epub+zip': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=epub',
#    'application/zip': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=zip',
#    'application/vnd.openxmlformats-officedocument.wordprocessingml.document': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=docx',
#    'text/plain': 'https://docs.google.com/feeds/download/documents/export/Export?id=1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY&exportFormat=txt'},
#   'parents': ['1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP'],
#   'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.document',
#   'shared': True,
#   'lastModifyingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'owners': [{'displayName': 'tinmar andrade',
#     'kind': 'drive#user',
#     'me': False,
#     'permissionId': '03209325635839904128',
#     'emailAddress': 'tinmar96@gmail.com',
#     'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}],
#   'webViewLink': 'https://docs.google.com/document/d/1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY/edit?usp=drivesdk',
#   'size': '1024',
#   'viewersCanCopyContent': True,
#   'hasThumbnail': False,
#   'spaces': ['drive'],
#   'id': '1LXlqSoMbnv7HUQ2UYNOFpmFXJ_vVZOGLtUoylnfi3bY',
#   'name': 'prueba',
#   'starred': False,
#   'trashed': False,
#   'explicitlyTrashed': False,
#   'createdTime': '2023-09-22T11:02:11.077Z',
#   'modifiedTime': '2023-09-22T11:02:25.022Z',
#   'quotaBytesUsed': '1024',
#   'version': '9',
#   'ownedByMe': False,
#   'isAppAuthorized': False,
#   'capabilities': {'canChangeViewersCanCopyContent': False,
#    'canEdit': False,
#    'canCopy': True,
#    'canComment': False,
#    'canAddChildren': False,
#    'canDelete': False,
#    'canDownload': True,
#    'canListChildren': False,
#    'canRemoveChildren': False,
#    'canRename': False,
#    'canTrash': False,
#    'canReadRevisions': False,
#    'canChangeCopyRequiresWriterPermission': False,
#    'canMoveItemIntoTeamDrive': False,
#    'canUntrash': False,
#    'canModifyContent': False,
#    'canMoveItemOutOfDrive': False,
#    'canAddMyDriveParent': False,
#    'canRemoveMyDriveParent': True,
#    'canMoveItemWithinDrive': False,
#    'canShare': False,
#    'canMoveChildrenWithinDrive': False,
#    'canModifyContentRestriction': False,
#    'canChangeSecurityUpdateEnabled': False,
#    'canAcceptOwnership': False,
#    'canReadLabels': False,
#    'canModifyLabels': False,
#    'canModifyEditorContentRestriction': False,
#    'canModifyOwnerContentRestriction': False,
#    'canRemoveContentRestriction': False},
#   'thumbnailVersion': '0',
#   'modifiedByMe': False,
#   'linkShareMetadata': {'securityUpdateEligible': False,
#    'securityUpdateEnabled': True}},
#  {'kind': 'drive#file',
#   'fileExtension': 'docx',
#   'copyRequiresWriterPermission': False,
#   'md5Checksum': '22fe5d3a333af51eb51568ceddb053a4',
#   'writersCanShare': True,
#   'viewedByMe': False,
#   'mimeType': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'parents': ['1y1XFty1aIIvAix3F8qpJMqnC_YiTIXyP'],
#   'thumbnailLink': 'https://lh3.googleusercontent.com/drive-storage/AKHj6E5uHAESdqAZDexfYzu6WzLvLUnna9oNh6o_3Jpr1jKl-FG6jTzMpoDv3p-hrVux5KyCOjgL3BeKllZsREOVKJ2H_RUfaUZNP2Ggc4pY=s220',
#   'iconLink': 'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'shared': True,
#   'lastModifyingUser': {'displayName': 'tinmar andrade',
#    'kind': 'drive#user',
#    'me': False,
#    'permissionId': '03209325635839904128',
#    'emailAddress': 'tinmar96@gmail.com',
#    'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'},
#   'owners': [{'displayName': 'tinmar andrade',
#     'kind': 'drive#user',
#     'me': False,
#     'permissionId': '03209325635839904128',
#     'emailAddress': 'tinmar96@gmail.com',
#     'photoLink': 'https://lh3.googleusercontent.com/a-/ALV-UjXldvH0MdGl-Oxfvx1OjxA-eacqpS1U-58U32DE5rwLJw=s64'}],
#   'headRevisionId': '0B19oBnxhxNcdRlhFNUU4NkxXOE5EZE5ERHdHTjRPZklVazZrPQ',
#   'webViewLink': 'https://docs.google.com/document/d/150N_1XagvRfLpIybz5lwOu2CwHkr2ocg/edit?usp=drivesdk&ouid=109730341896447223533&rtpof=true&sd=true',
#   'webContentLink': 'https://drive.google.com/uc?id=150N_1XagvRfLpIybz5lwOu2CwHkr2ocg&export=download',
#   'size': '11367',
#   'viewersCanCopyContent': True,
#   'hasThumbnail': True,
#   'spaces': ['drive'],
#   'id': '150N_1XagvRfLpIybz5lwOu2CwHkr2ocg',
#   'name': 'Diccionario de datos.docx',
#   'starred': False,
#   'trashed': False,
#   'explicitlyTrashed': False,
#   'createdTime': '2023-09-27T05:00:51.512Z',
#   'modifiedTime': '2023-09-16T02:19:22.000Z',
#   'quotaBytesUsed': '11367',
#   'version': '5',
#   'originalFilename': 'Diccionario de datos.docx',
#   'ownedByMe': False,
#   'fullFileExtension': 'docx',
#   'isAppAuthorized': False,
#   'capabilities': {'canChangeViewersCanCopyContent': False,
#    'canEdit': False,
#    'canCopy': True,
#    'canComment': False,
#    'canAddChildren': False,
#    'canDelete': False,
#    'canDownload': True,
#    'canListChildren': False,
#    'canRemoveChildren': False,
#    'canRename': False,
#    'canTrash': False,
#    'canReadRevisions': False,
#    'canChangeCopyRequiresWriterPermission': False,
#    'canMoveItemIntoTeamDrive': False,
#    'canUntrash': False,
#    'canModifyContent': False,
#    'canMoveItemOutOfDrive': False,
#    'canAddMyDriveParent': False,
#    'canRemoveMyDriveParent': True,
#    'canMoveItemWithinDrive': False,
#    'canShare': False,
#    'canMoveChildrenWithinDrive': False,
#    'canModifyContentRestriction': False,
#    'canChangeSecurityUpdateEnabled': False,
#    'canAcceptOwnership': False,
#    'canReadLabels': False,
#    'canModifyLabels': False,
#    'canModifyEditorContentRestriction': False,
#    'canModifyOwnerContentRestriction': False,
#    'canRemoveContentRestriction': False},
#   'thumbnailVersion': '1',
#   'modifiedByMe': False,
#   'linkShareMetadata': {'securityUpdateEligible': False,
#    'securityUpdateEnabled': True},
#   'sha1Checksum': '59c4faa6a65c78d9aae3636b1479a3f4531b961c',
#   'sha256Checksum': 'bbcd8355e383331213551af629859c1024c880733ef5a37c0a99561ab6999573'}]

# %%
results = service.drives().list().execute()
results.get('files', [])
# Out:
# []
