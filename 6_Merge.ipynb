# %%
import pandas as pd

# %%
df_california=pd.read_csv('df_california_clasificacion_comentarios.csv')
df_ny=pd.read_csv('df_ny_clasificacion_comentarios.csv')
df_texas=pd.read_csv('df_texas_clasificacion_comentarios.csv')
df_colorado=pd.read_csv('df_colorado_clasificacion_comentarios.csv')
df_georgia=pd.read_csv('df_georgia_clasificacion_comentarios.csv')

# %% [markdown]
# # Merge de todos los dataframes

# %%
df_google_maps = pd.concat([df_california, df_ny,df_texas,df_colorado,df_georgia])
df_google_maps
# Out:
#                 Usuario  Rating_Usuario  \
# 0               song ro               5
# 1           rafa robles               5
# 2             david han               4
# 3           anthony kim               5
# 4         mario marzouk               5
# ...                 ...             ...
# 976810  zachary vincent               1
# 976811    jeff marshall               1
# 976812              l s               4
# 976813    sidhant dewan               4
# 976814      fabio faria               5
#
#                                                    Review  \
# 0                             love there korean rice cake
# 1                                          good very good
# 2         they make korean traditional food very properly
# 3                           short ribs are very delicious
# 4            great food and prices the portions are large
# ...                                                   ...
# 976810  ended up with a headache because if the rides ...
# ...

# %%
df_google_maps.reset_index(drop=True, inplace=True)
df_google_maps
# Out:
#                  Usuario  Rating_Usuario  \
# 0                song ro               5
# 1            rafa robles               5
# 2              david han               4
# 3            anthony kim               5
# 4          mario marzouk               5
# ...                  ...             ...
# 5520373  zachary vincent               1
# 5520374    jeff marshall               1
# 5520375              l s               4
# 5520376    sidhant dewan               4
# 5520377      fabio faria               5
#
#                                                     Review  \
# 0                              love there korean rice cake
# 1                                           good very good
# 2          they make korean traditional food very properly
# 3                            short ribs are very delicious
# 4             great food and prices the portions are large
# ...                                                    ...
# ...

# %%
['kfc','mcdonalds','subway','pizza hut','dominos pizza']

# %%
df_google_maps.to_csv('df_google_maps.csv',index=False)
